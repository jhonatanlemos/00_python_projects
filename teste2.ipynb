# %%
import pandas as pd
arquivo_teste = pd.read_excel(r'C:\Users\jhonatan.lemos.gx2.GCSP-NTB071\OneDrive - DIAGNOSTICOS DA AMERICA S.A\Área de Trabalho\00.Diversos\01. Bases Boticario\Evolução Pisicologia 01.07.2019-31.07.2022.xlsx')
arquivo_teste = pd.DataFrame(arquivo_teste)
arquivo_teste.head(5)
# Out:
#   Relatório de Evolução Psicologia          Unnamed: 1  \
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                Código da Empresa  Apelido da Empresa
# 4                           897449         BELEZA.COM
#
#                   Unnamed: 2             Unnamed: 3          Unnamed: 4  \
# 0                        NaN                    NaN                 NaN
# 1                        NaN                    NaN                 NaN
# 2                        NaN                    NaN                 NaN
# 3            Nome da Empresa  Matrícula Funcionário  Código Funcionário
# 4  BELEZA.COM Prod Blza Serv                  18378                  29
#
#                           Unnamed: 5          Unnamed: 6      Unnamed: 7  \
# 0                                NaN                 NaN             NaN
# ...

# %%
print ("Hello World")
# Out:
# Hello World
